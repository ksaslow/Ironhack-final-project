# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('BLI_07022021180944760.csv')

pd.set_option("display.max_rows", None, "display.max_columns", None)
data
# Out:
#     LOCATION        Country  INDICATOR  \
# 0        DEU        Germany    CG_SENG
# 1        USA  United States    CG_SENG
# 2       OECD   OECD - Total    CG_SENG
# 3        DEU        Germany    HO_HISH
# 4        USA  United States    HO_HISH
# 5       OECD   OECD - Total    HO_HISH
# 6        DEU        Germany  PS_FSAFEN
# 7        USA  United States  PS_FSAFEN
# 8       OECD   OECD - Total  PS_FSAFEN
# 9        DEU        Germany  PS_FSAFEN
# 10       USA  United States  PS_FSAFEN
# 11      OECD   OECD - Total  PS_FSAFEN
# 12       DEU        Germany  PS_FSAFEN
# 13       USA  United States  PS_FSAFEN
# 14      OECD   OECD - Total  PS_FSAFEN
# 15       DEU        Germany    IW_HADI
# 16       USA  United States    IW_HADI
# 17      OECD   OECD - Total    IW_HADI
# 18       DEU        Germany    IW_HNFW
# 19       USA  United States    IW_HNFW
# 20      OECD   OECD - Total    IW_HNFW
# 21       DEU        Germany    JE_EMPL
# 22       USA  United States    JE_EMPL
# ...

# %%
data.columns
# Out:
# Index(['LOCATION', 'Country', 'INDICATOR', 'Indicator', 'MEASURE', 'Measure',
#        'INEQUALITY', 'Inequality', 'Unit Code', 'Unit', 'PowerCode Code',
#        'PowerCode', 'Reference Period Code', 'Reference Period', 'Value',
#        'Flag Codes', 'Flags'],
#       dtype='object')

# %%
data
# Out:
# (158, 17)
