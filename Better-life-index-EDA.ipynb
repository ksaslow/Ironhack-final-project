# %% [markdown]
# # Better Life Index (OECD Data)
#
# ### Cleaning the BLI dataset to use for analysis
# Link to data: https://stats.oecd.org/Index.aspx?DataSetCode=BLI

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('BLI_08022021212949491.csv')

pd.set_option("display.max_rows", None, "display.max_columns", None)
data
# Out:
#      LOCATION          Country  INDICATOR  \
# 0         AUS        Australia    JE_LMIS
# 1         AUT          Austria    JE_LMIS
# 2         BEL          Belgium    JE_LMIS
# 3         CAN           Canada    JE_LMIS
# 4         CZE   Czech Republic    JE_LMIS
# 5         DNK          Denmark    JE_LMIS
# 6         FIN          Finland    JE_LMIS
# 7         FRA           France    JE_LMIS
# 8         DEU          Germany    JE_LMIS
# 9         GRC           Greece    JE_LMIS
# 10        HUN          Hungary    JE_LMIS
# 11        ISL          Iceland    JE_LMIS
# 12        IRL          Ireland    JE_LMIS
# 13        ITA            Italy    JE_LMIS
# 14        JPN            Japan    JE_LMIS
# 15        KOR            Korea    JE_LMIS
# 16        LUX       Luxembourg    JE_LMIS
# 17        MEX           Mexico    JE_LMIS
# 18        NLD      Netherlands    JE_LMIS
# 19        NZL      New Zealand    JE_LMIS
# 20        POL           Poland    JE_LMIS
# ...

# %%
data.columns
# Out:
# Index(['LOCATION', 'Country', 'INDICATOR', 'Indicator', 'MEASURE', 'Measure',
#        'INEQUALITY', 'Inequality', 'Unit Code', 'Unit', 'PowerCode Code',
#        'PowerCode', 'Reference Period Code', 'Reference Period', 'Value',
#        'Flag Codes', 'Flags'],
#       dtype='object')

# %%
data.shape
# Out:
# (2369, 17)

# %% [markdown]
# ### Cleaning and re-structuring the data with pandas:
#
# ##### To do:
# * Grouping labels have been removed and the row for units of measurement for each column has been removed with the units added to the end of each column label as such: (Percentage: 'act pct'; Ratio: 'as rat'; US Dollar: 'in usd'; Average score: 'as avg score'; Years: 'in years'; Micrograms per cubic meter: 'in ugm3'; Hours: 'in hrs').
# * Drop indicators not important to my analysis
# * Drop countries not US/DE?
# * etc

# %%
"""How can I turn rows into columns? 
It looks like each country has a row for one indicator. 
How would I change this to turn each indicator into 
a column with the rows as 1 country with scores per indicator?"""
# Out:
# 'How can I turn rows into columns? It looks like each country has a row for one indicator. How would I change this to turn each indicator into a column with the rows as 1 country with scores per indicator?'

# %% [markdown]
# ### Look into pandas datareader for OECD data:
# https://readthedocs.org/projects/pandas-datareader/downloads/pdf/latest/

# %%
# pip install pandas-datareader

# %%
import pandas_datareader as pdr
import pandas_datareader.data as web

# %%
df = web.DataReader('BLI', 'oecd')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-c562c0994b3d> in <module>
# ----> 1 df = web.DataReader('BLI', 'oecd')
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     212                 else:
#     213                     kwargs[new_arg_name] = new_arg_value
# --> 214             return func(*args, **kwargs)
#     215
#     216         return cast(F, wrapper)
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas_datareader/data.py in DataReader(name, data_source, start, end, retry_count, pause, session, api_key)
#     473
#     474     elif data_source == "oecd":
# --> 475         return OECDReader(
#     476             symbols=name,
#     477             start=start,
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas_datareader/base.py in read(self)
# ...
