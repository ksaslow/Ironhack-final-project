# %%
# import sys
# !{sys.executable} -m pip install tweepy
import tweepy

# %%
import json
import tweepy
import pandas as pd

# %%
# This doesnt work (taken from class notes to refresh memory)

# cred = {}
# cred['API_KEY'] = API_KEY
# cred['API_SECRET'] = API_SECRET
# cred['ACCESS_TOKEN'] = ACCESS_TOKEN
# cred['ACCESS_TOKEN_SECRET'] = ACCESS_TOKEN_SECRET

# with open('twitter_credentials copy2.json', 'w') as outfile:
#     json.dump(cred, outfile)

# %%
#note: in case this doesnt work, I changed the name of the file (before it was "twitter_credentials copy.json") to add to gitignore
with open('twitter_credentials_copy.json', 'r') as infile:
    credentials = json.loads(infile.read())

# %%
print(credentials)
# Out:
# {'API_KEY': 'iKWX68iDw3Fhmm6P4PC0vCcAw', 'API_SECRET': 'BxseYvcYula7GLoLGvqTjArGUHb5hWgx374vbLee3dzcyTE1Xw', 'ACCESS_TOKEN': '979279794478206976-hbKrnVfnLEN8gsU622yvdhWTrD2mKjs', 'ACCESS_TOKEN_SECRET': 'GC5K93vSIrU8i3xnixznF4Wb677KqGsFUQ5Ml3kDsxgl9'}

# %% [markdown]
# ## Twitter API - documentation:
# https://docs.tweepy.org/en/latest/api.html

# %%
help(tweepy)

# need to create an authentication object to authenticate ourselves!
# Out:
# Help on package tweepy:
#
# NAME
#     tweepy - Tweepy Twitter API library
#
# PACKAGE CONTENTS
#     api
#     auth
#     binder
#     cache
#     cursor
#     error
#     models
#     parsers
#     streaming
#     utils
#
# FUNCTIONS
#     debug(enable=True, level=1)
#
# DATA
#     __license__ = 'MIT'
#     api = <tweepy.api.API object>
#
# VERSION
#     3.10.0
#
# AUTHOR
#     Joshua Roesslein
#
# FILE
#     /opt/anaconda3/lib/python3.8/site-packages/tweepy/__init__.py

# %%
auth = tweepy.OAuthHandler(credentials['API_KEY'], credentials['API_SECRET'])

# step 1: authenticate yourself
# this can be found in the authentication tutorial on the twitter developer page docs.

# %%
# step 2: set your tokens
# we need to now SET our access tokens
# this sets the tokens for you to actually be able to receive information from the API

auth.set_access_token(credentials['ACCESS_TOKEN'], credentials['ACCESS_TOKEN_SECRET'])

# %%
# step 3: generate your API
# now create our access to the API

api = tweepy.API(auth)

# %%
api.me()

# when working with complex APIs that require authentication, it is good to run a simple command like this at the very beginning
# so you can be sure that the authentication worked!
# Out:
# User(_api=<tweepy.api.API object at 0x10cdb45b0>, _json={'id': 979279794478206976, 'id_str': '979279794478206976', 'name': 'Kate Saslow', 'screen_name': 'kate_saslow', 'location': 'Berlin, Germany', 'profile_location': None, 'description': 'Research analyst and avid reader on all things #AI, #datascience, #feminism, #policy. All views my own. w/ @snv_berlin. Alumna of @thehertieschool @UMich.', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 588, 'friends_count': 959, 'listed_count': 15, 'created_at': 'Thu Mar 29 08:51:11 +0000 2018', 'favourites_count': 358, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 182, 'lang': None, 'status': {'created_at': 'Mon Feb 08 17:44:28 +0000 2021', 'id': 1358834091836194821, 'id_str': '1358834091836194821', 'text': 'RT @Fabian_Reetz: #Job-Alert 📣\nYou are into #sustainability or #energytransition and know how to code? \n\nWe at @100ProzentEE are looking fo…', 'truncated': False, 'entities': {'hashtags': [{'text': 'Job', 'indices': [18, 22]}, {'text': 'sustainability', 'indices': [44, 59]}, {'text': 'energytransition', 'indices': [63, 80]}], 'symbols': [], 'user_mentions': [{'screen_name': 'Fabian_Reetz', 'name': 'Fabian Reetz', 'id': 768089137291333632, 'id_str': '768089137291333632', 'indices': [3, 16]}, {'screen_name': '100ProzentEE', 'name': '100pes', 'id': 29702898, 'id_str': '29702898', 'indices': [111, 124]}], 'urls': []}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Feb 08 16:58:57 +0000 2021', 'id': 1358822639775678479, 'id_str': '1358822639775678479', 'text': '#Job-Alert 📣\nYou are into #sustainability or #energytransition and know how to code? \n\nWe at @100ProzentEE are look… https://t.co/KQRE1vUN96', 'truncated': True, 'entities': {'hashtags': [{'text': 'Job', 'indices': [0, 4]}, {'text': 'sustainability', 'indices': [26, 41]}, {'text': 'energytransition', 'indices': [45, 62]}], 'symbols': [], 'user_mentions': [{'screen_name': '100ProzentEE', 'name': '100pes', 'id': 29702898, 'id_str': '29702898', 'indices': [93, 106]}], 'urls': [{'url': 'https://t.co/KQRE1vUN96', 'expanded_url': 'https://twitter.com/i/web/status/1358822639775678479', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 3, 'favorite_count': 5, 'favorited': False, 'retweeted': True, 'possibly_sensitive': False, 'lang': 'en'}, 'is_quote_status': False, 'retweet_count': 3, 'favorite_count': 0, 'favorited': False, 'retweeted': True, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/979281087565361152/QYUE3fT2_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/979281087565361152/QYUE3fT2_normal.jpg', 'profile_link_color': '19CF86', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, ...

# %% [markdown]
# ### Play around with `api.search(q, [,geocode][,lang]...)`

# %% [markdown]
# ### Documentation: find twitter users based on their location:
# https://stackoverflow.com/questions/37017623/find-twitter-users-based-on-their-location

# %% [markdown]
# ### Geopy for finding geocodes (to use for filtering Twitter users):
# https://geopy.readthedocs.io/en/stable/# ,
# https://towardsdatascience.com/geocode-with-python-161ec1e62b89

# %%
# !pip install geopy
# Out:
# Requirement already satisfied: geopy in /opt/anaconda3/envs/kittycat/lib/python3.8/site-packages (2.1.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /opt/anaconda3/envs/kittycat/lib/python3.8/site-packages (from geopy) (1.50)

# %%
from geopy.geocoders import Nominatim

# %%
locator = Nominatim(user_agent="myGeocode")

berlin_geocode = locator.geocode('Berlin, Germany')
print("Latitude = {}, Longitude = {}".format(berlin_geocode.latitude, berlin_geocode.longitude))

dc_geocode = locator.geocode('Washington D.C., United States')
print("Latitude = {}, Longitude = {}".format(dc_geocode.latitude, dc_geocode.longitude))

chicago_geocode = locator.geocode('Chicago, Illinois, United States')
print("Latitude = {}, Longitude = {}".format(chicago_geocode.latitude, chicago_geocode.longitude))

seattle_geocode = locator.geocode('Seattle, Washington, United States')
print("Latitude = {}, Longitude = {}".format(seattle_geocode.latitude, seattle_geocode.longitude))
# Out:
# Latitude = 52.5170365, Longitude = 13.3888599
# Latitude = 38.8950368, Longitude = -77.0365427
# Latitude = 41.8755616, Longitude = -87.6244212
# Latitude = 47.6038321, Longitude = -122.3300624

# %%
# Making a query with twitter api:

query = 'AI'
geo = '52.5170365,13.3888599,250km'
cnt=10


tweets = [tweet for tweet in api.search(q = 'artificial intelligence', lang='en', geocode=geo, count=cnt)]
tweets
# Out:
# [Status(_api=<tweepy.api.API object at 0x1052b34c0>, _json={'created_at': 'Mon Feb 08 17:15:03 +0000 2021', 'id': 1358826690835861511, 'id_str': '1358826690835861511', 'text': 'The question is not whether you have 1 million interconnected cars worldwide, the question is which cities will all… https://t.co/CyW31viigL', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/CyW31viigL', 'expanded_url': 'https://twitter.com/i/web/status/1358826690835861511', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1010899417707241473, 'id_str': '1010899417707241473', 'name': 'Volkan', 'screen_name': 'volkan17658772', 'location': 'Berlin, Deutschland', 'description': 'TU Berlin, science and technology studies&sociology. Publishing on democracy, autonomous cars and spatial politics.', 'url': 'https://t.co/r733RLDmnU', 'entities': {'url': {'urls': [{'url': 'https://t.co/r733RLDmnU', 'expanded_url': 'https://www.sfb1265.de/en/people/volkan-sayman/', 'display_url': 'sfb1265.de/en/people/volk…', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 402, 'friends_count': 2142, 'listed_count': 4, 'created_at': 'Sun Jun 24 14:56:17 +0000 2018', 'favourites_count': 2196, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 705, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1349420996005163013/V1mafr7X_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1349420996005163013/V1mafr7X_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1010899417707241473/1562100688', 'profile_link_color': 'FAB81E', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': True, 'quoted_status_id': 1224043531951583233, 'quoted_status_id_str': '1224043531951583233', 'quoted_status': {'created_at': 'Sun Feb 02 18:54:54 +0000 2020', 'id': 1224043531951583233, 'id_str': '1224043531951583233', 'text': '“At Tesla, using AI to solve self-driving isn’t just icing on the cake, it the cake” - @lexfridman \n\nJoin AI at Tes… https://t.co/jQkNAReWlb', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'lexfridman', 'name': 'Lex Fridman', 'id': 427089628, 'id_str': '427089628', 'indices': [87, 98]}], 'urls': [{'url': 'https://t.co/jQkNAReWlb', 'expanded_url': 'https://twitter.com/i/web/status/1224043531951583233', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 44196397, 'id_str': '44196397', 'name': 'Elon Musk', 'screen_name': ...
#  Status(_api=<tweepy.api.API object at 0x1052b34c0>, _json={'created_at': 'Mon Feb 08 16:56:35 +0000 2021', 'id': 1358822044939546624, 'id_str': '1358822044939546624', 'text': 'RT @GTAI_com: Germany is at the forefront of artificial intelligence (#AI) in Europe. Discover innovative applications and projects as well…', 'truncated': False, 'entities': {'hashtags': [{'text': 'AI', 'indices': [70, 73]}], 'symbols': [], 'user_mentions': [{'screen_name': 'GTAI_com', 'name': 'Germany Trade & Invest', 'id': 407763358, 'id_str': '407763358', 'indices': [3, 12]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1430073499, 'id_str': '1430073499', 'name': 'Hans-Peter Bursig', 'screen_name': 'HPBursig', 'location': 'Frankfurt am Main, Deutschland', 'description': 'Beim ZVEI für den Leitmarkt Gesundheit zuständig. Schwerpunkt innovative Medizintechnik und Digitalisierung. Views are my own, corporate news via @ZVEIorg', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 327, 'friends_count': 120, 'listed_count': 3, 'created_at': 'Wed May 15 09:45:11 +0000 2013', 'favourites_count': 3567, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 5273, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1075332187975811072/iLKJskEN_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1075332187975811072/iLKJskEN_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1430073499/1545219574', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Feb 08 15:49:09 +0000 2021', 'id': 1358805073342660608, 'id_str': '1358805073342660608', 'text': 'Germany is at the forefront of artificial intelligence (#AI) in Europe. Discover innovative applications and projec… https://t.co/r0bZ1UOLkz', 'truncated': True, 'entities': {'hashtags': [{'text': 'AI', 'indices': [56, 59]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/r0bZ1UOLkz', 'expanded_url': 'https://twitter.com/i/web/status/1358805073342660608', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 407763358, 'id_str': '407763358', 'name': 'Germany Trade & Invest', 'screen_name': 'GTAI_com', 'location': 'Berlin', 'description': 'Germany Trade & Invest (GTAI) is the federal investment promotion agency of Germany. RT ≠ endorsement |  Imprint + Privacy Policy https://t.co/8eFo7jxVq8', 'url': 'http://t.co/KbHeIBAxWv', 'entities': {'url': {'urls': [{'url': 'http://t.co/KbHeIBAxWv', 'expanded_url': 'http://www.gtai.com', 'display_url': 'gtai.com', 'indi ...
#  Status(_api=<tweepy.api.API object at 0x1052b34c0>, _json={'created_at': 'Mon Feb 08 16:55:22 +0000 2021', 'id': 1358821737790636034, 'id_str': '1358821737790636034', 'text': 'RT @GTAI_com: Germany is at the forefront of artificial intelligence (#AI) in Europe. Discover innovative applications and projects as well…', 'truncated': False, 'entities': {'hashtags': [{'text': 'AI', 'indices': [70, 73]}], 'symbols': [], 'user_mentions': [{'screen_name': 'GTAI_com', 'name': 'Germany Trade & Invest', 'id': 407763358, 'id_str': '407763358', 'indices': [3, 12]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 905816509691416576, 'id_str': '905816509691416576', 'name': 'KI gestalten', 'screen_name': 'LernendeSysteme', 'location': 'München, Deutschland', 'description': 'Hier twittern Birgit Obermeier und Linda Treugut für die Plattform Lernende Systeme über #KI. Impressum: https://t.co/cwo9R37ktK', 'url': 'https://t.co/azCOCBpxws', 'entities': {'url': {'urls': [{'url': 'https://t.co/azCOCBpxws', 'expanded_url': 'http://www.plattform-lernende-systeme.de', 'display_url': 'plattform-lernende-systeme.de', 'indices': [0, 23]}]}, 'description': {'urls': [{'url': 'https://t.co/cwo9R37ktK', 'expanded_url': 'http://plattform-lernende-systeme.de/impressum.html', 'display_url': 'plattform-lernende-systeme.de/impressum.html', 'indices': [105, 128]}]}}, 'protected': False, 'followers_count': 3566, 'friends_count': 563, 'listed_count': 72, 'created_at': 'Thu Sep 07 15:34:19 +0000 2017', 'favourites_count': 2150, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 2296, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/907134890180784128/3sRVCg0u_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/907134890180784128/3sRVCg0u_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/905816509691416576/1505122355', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Feb 08 15:49:09 +0000 2021', 'id': 1358805073342660608, 'id_str': '1358805073342660608', 'text': 'Germany is at the forefront of artificial intelligence (#AI) in Europe. Discover innovative applications and projec… https://t.co/r0bZ1UOLkz', 'truncated': True, 'entities': {'hashtags': [{'text': 'AI', 'indices': [56, 59]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/r0bZ1UOLkz', 'expanded_url': 'https://twitter.com/i/web/status/1358805073342660608', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 407763358, 'id_str': '407763358', 'name': 'Germany Trade & Invest', 'screen_name': 'GTAI_com', 'location': 'Berlin', 'description': 'Germany Trade & Invest (GTAI) i ...
#  Status(_api=<tweepy.api.API object at 0x1052b34c0>, _json={'created_at': 'Mon Feb 08 16:05:30 +0000 2021', 'id': 1358809189959815168, 'id_str': '1358809189959815168', 'text': 'RT @T_Silberzahn: Jobs will be lost, gained, and changed in the face of AI: “The share of jobs and occupations ‘that can be fully automated…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'T_Silberzahn', 'name': 'Tobias Silberzahn', 'id': 2403148489, 'id_str': '2403148489', 'indices': [3, 16]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2870932446, 'id_str': '2870932446', 'name': 'Pgh Life Sciences', 'screen_name': 'PghLifeSciences', 'location': 'Pittsburgh, PA', 'description': 'The Pittsburgh Life Sciences Greenhouse is an investment firm committed to empowering entrepreneurs to build innovative and successful life sciences companies.', 'url': 'http://t.co/Ws7PSGTxM3', 'entities': {'url': {'urls': [{'url': 'http://t.co/Ws7PSGTxM3', 'expanded_url': 'http://www.plsg.com', 'display_url': 'plsg.com', 'indices': [0, 22]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 1709, 'friends_count': 1988, 'listed_count': 97, 'created_at': 'Wed Oct 22 13:16:02 +0000 2014', 'favourites_count': 3184, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 6076, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/524914297638375424/2J6azN1e_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/524914297638375424/2J6azN1e_normal.jpeg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2870932446/1427129726', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Feb 08 16:00:03 +0000 2021', 'id': 1358807816992157696, 'id_str': '1358807816992157696', 'text': 'Jobs will be lost, gained, and changed in the face of AI: “The share of jobs and occupations ‘that can be fully aut… https://t.co/XXiLByDo7Y', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/XXiLByDo7Y', 'expanded_url': 'https://twitter.com/i/web/status/1358807816992157696', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://www.linkedin.com/" rel="nofollow">LinkedIn</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2403148489, 'id_str': '2403148489', 'name': 'Tobias Silberzahn', 'screen_name': 'T_Silberzahn', 'location': 'Berlin', 'description': 'Partner at McKinsey focused on healthcare innovation. Member of the SCIANA Network', 'url': 'https://t.co/Ymg5Hmjqqo', 'entities': {'url': {'urls': [{'url': 'https://t.co/Ymg5Hmjqqo', 'expanded_url': 'https://www.linkedin.com/in/tobiassilberzahn/', 'dis ...
#  Status(_api=<tweepy.api.API object at 0x1052b34c0>, _json={'created_at': 'Mon Feb 08 16:00:03 +0000 2021', 'id': 1358807816992157696, 'id_str': '1358807816992157696', 'text': 'Jobs will be lost, gained, and changed in the face of AI: “The share of jobs and occupations ‘that can be fully aut… https://t.co/XXiLByDo7Y', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/XXiLByDo7Y', 'expanded_url': 'https://twitter.com/i/web/status/1358807816992157696', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://www.linkedin.com/" rel="nofollow">LinkedIn</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2403148489, 'id_str': '2403148489', 'name': 'Tobias Silberzahn', 'screen_name': 'T_Silberzahn', 'location': 'Berlin', 'description': 'Partner at McKinsey focused on healthcare innovation. Member of the SCIANA Network', 'url': 'https://t.co/Ymg5Hmjqqo', 'entities': {'url': {'urls': [{'url': 'https://t.co/Ymg5Hmjqqo', 'expanded_url': 'https://www.linkedin.com/in/tobiassilberzahn/', 'display_url': 'linkedin.com/in/tobiassilbe…', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 706, 'friends_count': 2312, 'listed_count': 8, 'created_at': 'Sat Mar 22 11:31:16 +0000 2014', 'favourites_count': 951, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 1846, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/907110107552600064/QZRuJTGg_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/907110107552600064/QZRuJTGg_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 1, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, created_at=datetime.datetime(2021, 2, 8, 16, 0, 3), id=1358807816992157696, id_str='1358807816992157696', text='Jobs will be lost, gained, and changed in the face of AI: “The share of jobs and occupations ‘that can be fully aut… https://t.co/XXiLByDo7Y', truncated=True, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/XXiLByDo7Y', 'expanded_url': 'https://twitter.com/i/web/status/1358807816992157696', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, metadata={'iso_language_code': 'en', 'result_type': 'recent'}, source='LinkedIn', source_url='http://www.linkedin.com/', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x1052b34c0>, _json={'id': 2403148489, 'id_str': '2403148489', 'name': 'Tobias Silberzahn', 'screen_name': 'T_Silberzahn', 'location': 'Berlin', 'description': 'Partner at McKinsey focused on healthcare innovation. Member of the SCIANA Network', 'url': 'https://t.co/Ymg5Hmjqqo', 'entities': {'url': {'urls': [{'url': 'https://t.co/Ymg5Hmjqqo', 'expanded_url': 'h ...
#  Status(_api=<tweepy.api.API object at 0x1052b34c0>, _json={'created_at': 'Mon Feb 08 15:49:09 +0000 2021', 'id': 1358805073342660608, 'id_str': '1358805073342660608', 'text': 'Germany is at the forefront of artificial intelligence (#AI) in Europe. Discover innovative applications and projec… https://t.co/r0bZ1UOLkz', 'truncated': True, 'entities': {'hashtags': [{'text': 'AI', 'indices': [56, 59]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/r0bZ1UOLkz', 'expanded_url': 'https://twitter.com/i/web/status/1358805073342660608', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 407763358, 'id_str': '407763358', 'name': 'Germany Trade & Invest', 'screen_name': 'GTAI_com', 'location': 'Berlin', 'description': 'Germany Trade & Invest (GTAI) is the federal investment promotion agency of Germany. RT ≠ endorsement |  Imprint + Privacy Policy https://t.co/8eFo7jxVq8', 'url': 'http://t.co/KbHeIBAxWv', 'entities': {'url': {'urls': [{'url': 'http://t.co/KbHeIBAxWv', 'expanded_url': 'http://www.gtai.com', 'display_url': 'gtai.com', 'indices': [0, 22]}]}, 'description': {'urls': [{'url': 'https://t.co/8eFo7jxVq8', 'expanded_url': 'http://gtai.com/imprint', 'display_url': 'gtai.com/imprint', 'indices': [130, 153]}]}}, 'protected': False, 'followers_count': 10120, 'friends_count': 665, 'listed_count': 229, 'created_at': 'Tue Nov 08 14:29:54 +0000 2011', 'favourites_count': 705, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': True, 'statuses_count': 4617, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/716977461079179268/JVN5NZO8_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/716977461079179268/JVN5NZO8_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/407763358/1459524280', 'profile_link_color': 'F00000', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': 'FFEA00', 'profile_text_color': '333333', 'profile_use_background_image': False, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 2, 'favorite_count': 3, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, created_at=datetime.datetime(2021, 2, 8, 15, 49, 9), id=1358805073342660608, id_str='1358805073342660608', text='Germany is at the forefront of artificial intelligence (#AI) in Europe. Discover innovative applications and projec… https://t.co/r0bZ1UOLkz', truncated=True, entities={'hashtags': [{'text': 'AI', 'indices': [56, 59]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/r0bZ1UOLkz', 'expanded_url': 'https://twitter.com/i/web/status/1358805073342660608', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, metadata={'iso_language_code': 'en', 'result_type': 'recent'}, source='Twitter Web App', source_url='https://mobile.twitter.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x1052b34c0>, _json={'id': 4077 ...

# %%
# extract the tweets by search query
tweets[0]._json
# Out:
# {'created_at': 'Mon Feb 08 17:15:03 +0000 2021',
#  'id': 1358826690835861511,
#  'id_str': '1358826690835861511',
#  'text': 'The question is not whether you have 1 million interconnected cars worldwide, the question is which cities will all… https://t.co/CyW31viigL',
#  'truncated': True,
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'user_mentions': [],
#   'urls': [{'url': 'https://t.co/CyW31viigL',
#     'expanded_url': 'https://twitter.com/i/web/status/1358826690835861511',
#     'display_url': 'twitter.com/i/web/status/1…',
#     'indices': [117, 140]}]},
#  'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#  'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 1010899417707241473,
#   'id_str': '1010899417707241473',
#   'name': 'Volkan',
#   'screen_name': 'volkan17658772',
#   'location': 'Berlin, Deutschland',
#   'description': 'TU Berlin, science and technology studies&sociology. Publishing on democracy, autonomous cars and spatial politics.',
#   'url': 'https://t.co/r733RLDmnU',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/r733RLDmnU',
#       'expanded_url': 'https://www.sfb1265.de/en/people/volkan-sayman/',
#       'display_url': 'sfb1265.de/en/people/volk…',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 402,
#   'friends_count': 2142,
#   'listed_count': 4,
#   'created_at': 'Sun Jun 24 14:56:17 +0000 2018',
#   'favourites_count': 2196,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 705,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '000000',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1349420996005163013/V1mafr7X_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1349420996005163013/V1mafr7X_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1010899417707241473/1562100688',
#   'profile_link_color': 'FAB81E',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': '000000',
#   'profile_text_color': '000000',
#   'profile_use_background_image': False,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none'},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'is_quote_status': True,
#  'quoted_status_id': 1224043531951583233,
#  'quoted_status_id_str': '1224043531951583233',
#  'quoted_status': {'created_at': 'Sun Feb 02 18:54:54 +0000 2020',
#   'id': 1224043531951583233,
#   'id_str': '1224043531951583233',
#   'text': '“At Tesla, using AI to solve self-driving isn’t just icing on the cake, it the cake” - @lexfridman \n\nJoin AI at Tes… https://t.co/jQkNAReWlb',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'lexfridman',
#      'name': 'Lex Fridman',
#      'id': 427089628,
#      'id_str': '427089628',
#      'indices': [87, 98]}],
#    'urls': [{'url': 'https://t.co/jQkNAReWlb',
#      'expanded_url': 'https://twitter.com/i/web/status/1224043531951583233',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 44196397,
#    'id_str': '44196397',
#    'name': 'Elon Musk',
#    'screen_name': 'elonmusk',
#    'location': '',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 46155324,
#    'friends_count': 103,
#    'listed_count': 63018,
#    'created_at': 'Tue Jun 02 20:12:29 +0000 2009',
#    'favourites_count': 8038,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 13545,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1295975423654977537/dHw9JcrK_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1295975423654977537/dHw9JcrK_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/44196397/1576183471',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 4995,
#   'favorite_count': 44371,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  'retweet_count': 0,
#  'favorite_count': 1,
#  'favorited': False,
#  'retweeted': False,
#  'possibly_sensitive': False,
#  'lang': 'en'}

# %% [markdown]
# #### Filter through my Twitter followers by their location:
# https://underthecurve.github.io/jekyll/update/2017/08/02/twitter-followers.html

# %%
api.followers?

# %%
# users = [user for user in api.followers('id', 'screen_name', count=250)]
# users

# %% [markdown]
# ### Make a dataframe with my Friends:

# %%
# function from SNV twitter network:

def get_friends(user):
    """ returns a list of friends (twitter_handle) of a user"""
    friends = []
    n=0
    for page in tweepy.Cursor(api.friends, screen_name=user, count=200).pages():
        n+=1
        print(f"Page number {n}")
        friends.extend(page)
#       time.sleep(60)
        return (friends)

kate_friends = get_friends("kate_saslow")
# Out:
# Page number 1

# %%
kate_friends[0]._json
# Out:
# {'id': 43342160,
#  'id_str': '43342160',
#  'name': 'Treva B',
#  'screen_name': 'divafeminist',
#  'location': 'All Ovah the World',
#  'description': 'Prof @ OSU/feminist/dancer/friend/daughter/auntie/she-her-hers in the struggle 4 justice. Buy my “Choice Outstanding Academic Title” #ColoredNoMore',
#  'url': 'https://t.co/jEKUkeeX2C',
#  'entities': {'url': {'urls': [{'url': 'https://t.co/jEKUkeeX2C',
#      'expanded_url': 'https://wgss.osu.edu/people/lindsey.268',
#      'display_url': 'wgss.osu.edu/people/lindsey…',
#      'indices': [0, 23]}]},
#   'description': {'urls': []}},
#  'protected': False,
#  'followers_count': 25786,
#  'friends_count': 1958,
#  'listed_count': 270,
#  'created_at': 'Fri May 29 14:46:04 +0000 2009',
#  'favourites_count': 60103,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': False,
#  'verified': False,
#  'statuses_count': 44834,
#  'lang': None,
#  'status': {'created_at': 'Mon Feb 08 19:13:24 +0000 2021',
#   'id': 1358856475418984449,
#   'id_str': '1358856475418984449',
#   'text': 'Really excited for this event tonight. Always a joy to be in convo with my sis @milfinainteasy. Also, I am beyond t… https://t.co/QHv7oLCMnl',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'milfinainteasy',
#      'name': 'Joan Morgan, Ph.D',
#      'id': 130366575,
#      'id_str': '130366575',
#      'indices': [79, 94]}],
#    'urls': [{'url': 'https://t.co/QHv7oLCMnl',
#      'expanded_url': 'https://twitter.com/i/web/status/1358856475418984449',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': True,
#   'quoted_status_id': 1358773451402657793,
#   'quoted_status_id_str': '1358773451402657793',
#   'retweet_count': 0,
#   'favorite_count': 3,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  'contributors_enabled': False,
#  'is_translator': False,
#  'is_translation_enabled': False,
#  'profile_background_color': 'C0DEED',
#  'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_tile': False,
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/1353731550957993985/4BQ9MiTP_normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1353731550957993985/4BQ9MiTP_normal.jpg',
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/43342160/1409957958',
#  'profile_link_color': '1DA1F2',
#  'profile_sidebar_border_color': 'C0DEED',
#  'profile_sidebar_fill_color': 'DDEEF6',
#  'profile_text_color': '333333',
#  'profile_use_background_image': True,
#  'has_extended_profile': True,
#  'default_profile': True,
#  'default_profile_image': False,
#  'following': True,
#  'live_following': False,
#  'follow_request_sent': False,
#  'notifications': False,
#  'muting': False,
#  'blocking': False,
#  'blocked_by': False,
#  'translator_type': 'none'}

# %%
names_friends = [kate_friends[i]._json['name'] for i in range(len(kate_friends))]

# %%
handles_friends = [kate_friends[i]._json['screen_name'] for i in range(len(kate_friends))]

# %%
locations_friends = [kate_friends[i]._json['location'] for i in range(len(kate_friends))]

# %%
descriptions_friends = [kate_friends[i]._json['description'] for i in range(len(kate_friends))]

# %%
friends_df = pd.DataFrame(zip(names_friends, handles_friends, locations_friends, descriptions_friends))
friends_df.rename(columns={0:'Friend', 1:'Handle', 2:'Location', 3:'UserDescription'}, inplace=True)
friends_df
# Out:
#              Friend          Handle            Location  \
# 0           Treva B    divafeminist  All Ovah the World
# 1          Veronika  VeronikaDatzer              Berlin
# 2    Christina Rupp  christinacrupp   Bonn, Deutschland
# 3             Clara   thatclarafied     Los Angeles, CA
# 4       John Miller    JohnMillerTX      Fort Worth, TX
# ..              ...             ...                 ...
# 195          Esther         es_kern             Germany
# 196   Anna Cardillo   annacardillo_              Berlin
# 197    Nils Leopold     NilsLeopold     Berlin, Germany
# 198  Bart Hoogeveen   BartHoogeveen            Canberra
# 199   Sabine Ponath    sabineponath              Berlin
#
#                                        UserDescription
# 0    Prof @ OSU/feminist/dancer/friend/daughter/aun...
# 1    International Relations @FU_Berlin, Assistant ...
# 2    Project Assistant International Cybersecurity ...
# 3    Writer | Comedian | Tech | Diversity & Inclusi...
# 4    #Analytics leader dealing in #machinelearning,...
# ..                                                 ...
# 195  🇪🇺 Research Fellow @BIGS_Potsdam | @Polis180 |...
# 196  Datenschutz-|Informationssicherheitsrecht|Busi...
# 197                                             Berlin
# 198  🇪🇺 with @ASPI_ICPC leading on #CyberCapacityBu...
# 199  Privat politisch // Podcast FAMILIENpolitisch ...
#
# [200 rows x 4 columns]

# %%
len(friends_df['Handle'])

# why are there only 20 friends?
# Out:
# 200

# %% [markdown]
# ### Make dataframe with my Followers:

# %%
# function from twitter SNV analysis:

def get_follower(user):
    '''Returns a list of all follower (twitter_handle) of a user
    taking into account twitter API's request frequency limits'''
    follower = []
    n=0
    for page in tweepy.Cursor(api.followers, screen_name=user, count=200).pages():
        n+=1
        print(f"Page number {n}")
        follower.extend(page)
#       time.sleep(60)
    #screen_names = [user.screen_name for user in friends]
    return (follower)

kate = get_follower('kate_saslow')
kate[0]
# Out:
# Page number 1
# Page number 2
# Page number 3
# User(_api=<tweepy.api.API object at 0x10cdb45b0>, _json={'id': 989902718637608961, 'id_str': '989902718637608961', 'name': 'Christina Rupp', 'screen_name': 'christinacrupp', 'location': 'Bonn, Deutschland', 'description': 'Project Assistant International Cybersecurity Policy @snv_berlin', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 24, 'friends_count': 192, 'listed_count': 0, 'created_at': 'Fri Apr 27 16:22:54 +0000 2018', 'favourites_count': 4, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 1, 'lang': None, 'status': {'created_at': 'Thu Dec 17 19:55:23 +0000 2020', 'id': 1339660483541000193, 'id_str': '1339660483541000193', 'text': 'RT @z_edian: Unser @snv_berlin Expert:innenworkshop zur "staatlichen Beantwortung von böswilligen Cyberaktivitäten" geht langsam zuende.\n\nD…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'z_edian', 'name': 'Sven Herpig', 'id': 250064912, 'id_str': '250064912', 'indices': [3, 11]}, {'screen_name': 'snv_berlin', 'name': 'Stiftung Neue Verantwortung', 'id': 3012497357, 'id_str': '3012497357', 'indices': [19, 30]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Thu Dec 17 17:15:35 +0000 2020', 'id': 1339620266369052672, 'id_str': '1339620266369052672', 'text': 'Unser @snv_berlin Expert:innenworkshop zur "staatlichen Beantwortung von böswilligen Cyberaktivitäten" geht langsam… https://t.co/eusujTHTnK', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'snv_berlin', 'name': 'Stiftung Neue Verantwortung', 'id': 3012497357, 'id_str': '3012497357', 'indices': [6, 17]}], 'urls': [{'url': 'https://t.co/eusujTHTnK', 'expanded_url': 'https://twitter.com/i/web/status/1339620266369052672', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 3, 'favorite_count': 10, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'de'}, 'is_quote_status': False, 'retweet_count': 3, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'de'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1353604959011540992/j5ZprJ8I_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1353604959011540992/j5ZprJ8I_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': True, 'live_following': False, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'blocking': False, 'blocked_by': False, 'translator_type': 'none'}, id=989902718637608961, id_str='989902718637608961', name='Christina Rupp', screen_name='christinacrupp', location='Bonn, Deutschland', description='Project Assistant International Cybersecurity Policy @snv_berlin', url=None, entities={'description': {'urls': []}},  ...

# %%
type(kate[0]._json)
# Out:
# dict

# %%
kate[0]._json
# Out:
# {'id': 989902718637608961,
#  'id_str': '989902718637608961',
#  'name': 'Christina Rupp',
#  'screen_name': 'christinacrupp',
#  'location': 'Bonn, Deutschland',
#  'description': 'Project Assistant International Cybersecurity Policy @snv_berlin',
#  'url': None,
#  'entities': {'description': {'urls': []}},
#  'protected': False,
#  'followers_count': 24,
#  'friends_count': 192,
#  'listed_count': 0,
#  'created_at': 'Fri Apr 27 16:22:54 +0000 2018',
#  'favourites_count': 4,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': False,
#  'verified': False,
#  'statuses_count': 1,
#  'lang': None,
#  'status': {'created_at': 'Thu Dec 17 19:55:23 +0000 2020',
#   'id': 1339660483541000193,
#   'id_str': '1339660483541000193',
#   'text': 'RT @z_edian: Unser @snv_berlin Expert:innenworkshop zur "staatlichen Beantwortung von böswilligen Cyberaktivitäten" geht langsam zuende.\n\nD…',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'z_edian',
#      'name': 'Sven Herpig',
#      'id': 250064912,
#      'id_str': '250064912',
#      'indices': [3, 11]},
#     {'screen_name': 'snv_berlin',
#      'name': 'Stiftung Neue Verantwortung',
#      'id': 3012497357,
#      'id_str': '3012497357',
#      'indices': [19, 30]}],
#    'urls': []},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Thu Dec 17 17:15:35 +0000 2020',
#    'id': 1339620266369052672,
#    'id_str': '1339620266369052672',
#    'text': 'Unser @snv_berlin Expert:innenworkshop zur "staatlichen Beantwortung von böswilligen Cyberaktivitäten" geht langsam… https://t.co/eusujTHTnK',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'snv_berlin',
#       'name': 'Stiftung Neue Verantwortung',
#       'id': 3012497357,
#       'id_str': '3012497357',
#       'indices': [6, 17]}],
#     'urls': [{'url': 'https://t.co/eusujTHTnK',
#       'expanded_url': 'https://twitter.com/i/web/status/1339620266369052672',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 3,
#    'favorite_count': 10,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'de'},
#   'is_quote_status': False,
#   'retweet_count': 3,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'de'},
#  'contributors_enabled': False,
#  'is_translator': False,
#  'is_translation_enabled': False,
#  'profile_background_color': 'F5F8FA',
#  'profile_background_image_url': None,
#  'profile_background_image_url_https': None,
#  'profile_background_tile': False,
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/1353604959011540992/j5ZprJ8I_normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1353604959011540992/j5ZprJ8I_normal.jpg',
#  'profile_link_color': '1DA1F2',
#  'profile_sidebar_border_color': 'C0DEED',
#  'profile_sidebar_fill_color': 'DDEEF6',
#  'profile_text_color': '333333',
#  'profile_use_background_image': True,
#  'has_extended_profile': False,
#  'default_profile': True,
#  'default_profile_image': False,
#  'following': True,
#  'live_following': False,
#  'follow_request_sent': False,
#  'notifications': False,
#  'muting': False,
#  'blocking': False,
#  'blocked_by': False,
#  'translator_type': 'none'}

# %%
names_followers = [kate[i]._json['name'] for i in range(len(kate))]

# %%
handles_followers = [kate[i]._json['screen_name'] for i in range(len(kate))]

# %%
locations_followers = [kate[i]._json['location'] for i in range(len(kate))]

# %%
descriptions_followers = [kate[i]._json['description'] for i in range(len(kate))]

# %%
followers_df = pd.DataFrame(zip(names_followers,handles_followers, locations_followers, descriptions_followers))
followers_df.rename(columns={0:'Follower', 1:'Handle', 2:'Location', 3:'UserDescription'}, inplace=True)
followers_df

# will eventually need to clean to standardize how the location is formatted (e.g. by country only)
# Out:
#                         Follower          Handle              Location  \
# 0                 Christina Rupp  christinacrupp     Bonn, Deutschland
# 1                Johanna Schäfer         joscchh     Bonn, Deutschland
# 2                    John Miller    JohnMillerTX        Fort Worth, TX
# 3                  Rosanna Fanni    rosannafanni
# 4                    Lottie Lane     lottielane_  Groningen, Nederland
# ..                           ...             ...                   ...
# 583  Stiftung Neue Verantwortung      snv_berlin                Berlin
# 584                    Sasquatch  SirJacobSaslow
# 585              Nikolas Reschen       n_reschen      Wien, Österreich
# 586                    goldklang       goldkl4ng         Ann Arbor, MI
# 587        Rodrigo Jiménez Silva      jimenezroy
#
#                                        UserDescription
# 0    Project Assistant International Cybersecurity ...
# 1    CEO @BonnLAB, urban developer & #SocialMedia e...
# 2    #Analytics leader dealing in #machinelearning,...
# 3      monitoring the European public-political sphere
# 4    Assistant Prof. and Postdoc at @univgroningen\...
# ..                                                 ...
# 583  Der Think Tank Stiftung Neue Verantwortung arb...
# 584                 Clear eyes, full hearts, cant lose
# 585  Some sort of Scientist / Labour Market, Educat...
# 586  (he/him) Birds of Detroit: https://t.co/adrMv8...
# 587  Working on #climate policy | Podcaster🎙 🇲🇽 @th...
#
# [588 rows x 4 columns]

# %% [markdown]
# ### Write function that gets tweets by looping through the friends/followers in the list comprehensions above:

# %%
def get_tweets(handle):

    # extract 200 tweets
    number_tweets = 200
    tweets = api.user_timeline(screen_name=handle)

    # Empty array
    tmp = []

    # create array of tweet info: username, tweet id, date/time, text
    tweets_for_csv = [tweet.text for tweet in tweets] 

    for j in tweets_for_csv:
        tmp.append(j)
    

    return tmp

# %%
# test it to see if it worked, then apply loop to list comp.
get_tweets('SirJacobSaslow')

# %% [markdown]
# ### It seems that extracting the tweets' metadata worked.
# Now try it on all Followers rather than just the first 5!
# Note: stick with Followers, not friends! Friends maxes out at only 200, whereas with followers I can get tweets from the 500+ who follow me.
# Control for number extracted, as well as whether to use friends or followers before testing.
# Choose count=2000?
# Or potentially, look at Friends (people who I follow) df to see the location and make 2 dfs (one US, one DE), then run the code on the two divided dfs separately?

# %%
handles = list(followers_df['Handle'])
handles
# Out:
# ['christinacrupp',
#  'joscchh',
#  'JohnMillerTX',
#  'rosannafanni',
#  'lottielane_',
#  'TobiTheScholz',
#  'mnedbrussels',
#  'StKenner',
#  'fran_digital',
#  'jas_abroad',
#  'EgonHuschitt',
#  'liradelira0',
#  'KamasaJulian',
#  'EmiliaNeuber',
#  'mattreiner',
#  'NinoMacha',
#  'E_Dorokhova',
#  'sa_zeet',
#  'louisjarvers',
#  'verenawingerter',
#  'r_brendel',
#  'machinelearnflx',
#  'askans',
#  'HeidiObermeyer',
#  'GerritW24',
#  'ralf_ladner',
#  'DennisW16677051',
#  'andrea_no_',
#  'relationserieu5',
#  'Ely_anon_',
#  'stormy_mildner',
#  'samarabell1818',
#  'AlexTuc22110441',
#  '_MUNIYANquantum',
#  'Egels14',
#  'JLMellentin',
#  'PolicyIsrael',
#  'adahlma',
#  'LewinFricke',
#  'kat_lampert',
#  'SF_Dietlmeier',
#  'teamrework',
#  'denialstein',
#  'tjolp',
#  'thehertieschool',
#  'MALAKSA55400906',
#  'RaquelJorgeR',
#  'ForhadulFoysal',
#  'Beckswunderland',
#  'LordElend',
#  'laurajakli',
#  'snazzyazzy',
#  'HannesMehrer',
#  'Tobias__Wolf',
#  'BenediktBrecht',
#  'Keji94771336',
#  'andre_weisser',
#  'fedcar89',
#  'suyak',
#  'spielkamp',
#  'brankamarijan',
#  'GrinspoonMr',
#  'KMansted',
#  'BenSRachinger',
#  'TheLastEuropean',
#  'boell_digi',
#  'gracev0102',
#  'pinkiundbrain',
#  'echobit',
#  'Lawchenmann',
#  'jcagundlach',
#  'NessiWi',
#  'eideseder',
#  'leotanczt',
#  'mlaaff',
#  'AIClubGenderMin',
#  'friedrich_huff',
#  'N_S_Fouad',
#  'Zhaey_',
#  'jgvazzana',
#  'Melonika_',
#  'AHG_Berlin',
#  'witte_sb',
#  'domspiers',
#  'eleftheriats96',
#  'ajlakolenda',
#  'JanaKlawitter',
#  'NinaOW1',
#  'esreffbey',
#  'AutomateEstate',
#  'MichaelBarth',
#  'HannahBohle',
#  'jpbrice',
#  'DrJoeBurton',
#  'KatjaTheo',
#  'PeterDauvergne',
#  'noatamir',
#  'TammoNieter',
#  'InfoSecCat',
#  'senbiegler',
#  'martinmodlinger',
#  'FlorianLucks',
#  'smnrtz',
#  'Kris_de_Burg',
#  'TosoBruna',
#  'colleen_chen_',
#  'dietricharlotte',
#  'henningsway',
#  'kerstin_zettl',
#  'IDTheftCenter',
#  'akhildeo94',
#  'ethicist_arbor',
#  'i_skierka',
#  'ellajakubowska1',
#  'GoukensLode',
#  'eren__sozuer',
#  'veeebka',
#  'VeronikaDatzer',
#  'PaulGerhards1',
#  'OskarGstrein',
#  'AWagenplast',
#  'JoeWestby',
#  'al_hohlfeld',
#  'dws_ch',
#  'feichtner',
#  'nosy_noah',
#  'georges_delrieu',
#  'woodme2',
#  'LyndaIroulo',
#  'annegretbendiek',
#  'CyberPeace1',
#  'JohannaPolle',
#  'NielsRenssen',
#  'nadjaskaljic',
#  'El_Giesemann',
#  'mobilistig',
#  'Ale_RA08',
#  'ZerodayZero',
#  'TheRealAiBot',
#  'johkruse',
#  'stealthlabsinc',
#  'elemendar',
#  'franzidrauz',
#  'CharlotteKais10',
#  'EU_Bonn',
#  'hanschmannchr',
#  'Michael97889142',
#  'sugrobovas',
#  '4n7o1ne',
#  'geode_science',
#  'nudnik',
#  'entust1',
#  'Vidmish22',
#  'v_hunanyan',
#  'hagemeier_m',
#  'fl_cyber',
#  'TheRobCollett',
#  'GroovyHeuvy',
#  'margot_os',
#  'Bo_Datenschutz',
#  'M_Miho_JPN',
#  'tikle_se',
#  '0x614C0',
#  'es_kern',
#  'rout',
#  'Niklowski',
#  'otto_muck',
#  'annacardillo_',
#  'NilsLeopold',
#  'bknu',
#  'BartHoogeveen',
#  'sabineponath',
#  'J_B_C16',
#  'temilasade',
#  'wierzbicka01',
#  'MichaelAZanette',
#  'rmbeigel',
#  'Cyber4Dev',
#  'RCsernatoni',
#  'JackRya09297692',
#  'svenweizenegger',
#  'seosamhreamonn',
#  'theJanRau',
#  '_randolf_carr_',
#  'ayhangucuyener',
#  'AlexKlepel',
#  'KathaMars',
#  'lorandreoli',
#  'LinaRusch',
#  'AchbergerBrita',
#  'atul_jalan',
#  'e2hln',
#  'EmilyCSharpe',
#  'jules__george',
#  'DERYA_KOC2',
#  'twidlok',
#  'JoswigJulian',
#  'Belsaza',
#  'tinahuang__',
#  'patrykpawlak',
#  'juliaebert_',
#  'Alessandra_lv',
#  'FeraySe',
#  'TIMA_Martina',
#  'mona_sloane',
#  'CBradleyTweets',
#  'VidushiMarda',
#  'PhilippOtto',
#  'msdionis',
#  'laturquerie',
#  'AnikaLange1',
#  'MarekJSzczygiel',
#  'franzibus',
#  'ekenyanito',
#  'VatsAntara',
#  'CatherineGvh',
#  'nielsschia',
#  'cy_b0x',
#  'xiangshengwan',
#  'olasom',
#  'the_diplomark',
#  'Mark51181063',
#  'simonbreuckmann',
#  'EijaLeino',
#  'infofannny',
#  '_stani_slava_',
#  'M_Verde',
#  'AaptiEcolab',
#  'louisa_plasberg',
#  't_bazz',
#  'HeleneFouquet',
#  'TobiasLiebetrau',
#  'austchan',
#  'rgorwa',
#  'KthrnMeyer',
#  'konregen',
#  'deepthings',
#  'AG_KRITIS',
#  'MaxMustermann_1',
#  'hermannbella',
#  'Viviana_Zhu',
#  'Zerospam',
#  'aboutintel',
#  'SmartCountryCon',
#  'BRob2407',
#  'TheAndreCramer',
#  'amandakraley',
#  'ivoscherrer',
#  'A_Kerschbaum',
#  'flodexl',
#  'jupawlak',
#  'harry_cooney',
#  'PiaBLN',
#  'mil_kl',
#  'ellen_sch',
#  'M__Verbruggen',
#  'radiocatherine',
#  'konrad_de',
#  'thiernab',
#  'ae_fernandes',
#  'Datev_Politik',
#  'josuagrw',
#  'p_olbrich',
#  'DavidGraw03',
#  'insideNiMA',
#  'F_Kaltheuner',
#  'octopuscitizen',
#  'winter_elis',
#  'karenojeffrey',
#  'felicitashenni',
#  'lnrthm',
#  'Mazebolt',
#  'nhs281',
#  'hatr',
#  'SeeMarek',
#  'laza',
#  'francoisdelerue',
#  'neuromalte',
#  'NLnachrichten',
#  'Gonzale03989022',
#  'melissa_berko',
#  'j2bryson',
#  'PAHanania',
#  'zittrain',
#  'KenzieInBerlin',
#  'ale_paulus',
#  'GoldenerWesten',
#  'celinefroehlich',
#  'JeffreyClinto12',
#  'Ani_Klin',
#  'JacobusLein',
#  'CyberInAfrica',
#  'Aline19276462',
#  'Tarekk_Alex',
#  'MaxKoschyk',
#  'FarhanJanjua',
#  're_zehzett',
#  'JoyDantongMa',
#  'KevinAllison',
#  'BlinksSwith',
#  'KennethGeers',
#  'Jenica_A_Lewis',
#  'mowedel',
#  'HarrisCyber',
#  'Stephen56906745',
#  'annapellegatta',
#  'Geo_X_',
#  'rosina29972274',
#  'boell_secpol',
#  'privacy__ninja',
#  'Roguski_P',
#  'imdad132',
#  'joshjonsmith',
#  'ByronBergren',
#  'ITU_AIForGood',
#  'ZeerakW',
#  'justMathana',
#  'RobMcCargow',
#  'NTusikov',
#  'DwightAlex6',
#  'schlue_a',
#  'ErikBrattberg',
#  'DominikPietron',
#  'CPiallat',
#  'RebeccaArcesati',
#  'ryjharris',
#  'ckoever',
#  'markadasin12',
#  'ER_amitksingh',
#  'SebMeineck',
#  'DBMeinhard',
#  'sonyaong',
#  'KaanSahinDe',
#  'filterbabbel',
#  'sun4grid',
#  'redteamriley',
#  'SecEvangelism',
#  'BenedictDel',
#  'redmonkey_',
#  '1v3hK',
#  'corrieaar',
#  'MCKettemann',
#  'TanyaShoshan',
#  'S_Witry',
#  'ChristianDrerup',
#  'apilipis',
#  'jsotterbach',
#  'Fabian_Reetz',
#  'neuroprinciples',
#  'SammSacks',
#  'kstathou',
#  'perhaps_ai',
#  'plarkin_',
#  'hinataSec',
#  'adversariel',
#  'HonkHase',
#  'dgohla',
#  'xymenakurowska',
#  'MatzkiH',
#  'frankeschoen',
#  'N_Damschke',
#  'lietzkow',
#  'JJaursch',
#  'DocStefflbauer',
#  'FrauenLoop',
#  'RiyaJai42366108',
#  'KDRrecruitment',
#  'ValentinoGrass4',
#  'GreensteinAD',
#  'FilipBakaluca',
#  'busylady1013',
#  'kraychecker',
#  'AbrahamAttorney',
#  'DKorenke',
#  'TimPhSchaefers',
#  'notacomposer',
#  'Aristot73',
#  'info_sec_girl',
#  'Dinah_Davis',
#  'MichelleGlauser',
#  'toppolawrence',
#  'prototypefund',
#  'avwgo',
#  'bberlin',
#  'djleufer',
#  'caromoeckel',
#  'LeonieBeining',
#  'AdamToor4',
#  'IsabelRedies',
#  'ARGohdes',
#  'Salah777Ali',
#  'Digital_im_DRK',
#  'HawkinsTammy',
#  'PriyaSophia',
#  'databreachbot',
#  'smych',
#  'realDa_Kir',
#  'atlanticcom',
#  'JspClayton',
#  'castrotech',
#  'Sergey26055092',
#  'CusimanoF',
#  'jlpilon76',
#  'Demokratie2100',
#  'TobiJerzi',
#  'newsvieth',
#  'sunil_abraham',
#  'elonnai',
#  'foobard',
#  'ResearcHersCode',
#  'Matrix42_global',
#  'WoSECtweets',
#  'MaximilianKupi',
#  'subichaturvedi',
#  'Nedfire23',
#  'maxinefowe',
#  'keiam',
#  'joe27512869',
#  'nikschee',
#  'algoaware',
#  'kosmopolit',
#  'Valerie_fvv',
#  'IPZ_ch',
#  'rudizee',
#  'an_dreaskern',
#  'bernhardbartsch',
#  'dsplittgerber',
#  'SebWe_KAS',
#  'Lisa_Schmechel',
#  'cnewster',
#  'mgahntz',
#  'herrhamich',
#  'luciacizmaziova',
#  'hiseanlong',
#  'milan_thies',
#  'Anne46237871',
#  'BenWCole',
#  'SCHinBonn',
#  'fredschorn',
#  'LukasAPosch',
#  'RikeFranke',
#  'j_l_callahan',
#  'subhodeepjash',
#  'AnnyBoc',
#  'JohnMaynardCPA',
#  'hgrevepolsci',
#  'amykmcl',
#  'miguelitoj89',
#  'zetelegraph',
#  'JE_SIRIUS',
#  'YCW_Global',
#  'ViktoriaGrzymek',
#  'DilankaAmarako1',
#  'NSArchiveCyber',
#  'PaulTimmers',
#  'anushkacyber',
#  'eilah_tan',
#  'to_scho',
#  'dktatlow',
#  'TekendraSharma',
#  'laurajgroenen',
#  'EUCyberDirect',
#  'Liliann_F',
#  'smn_says',
#  'DataInnovation',
#  'gesine_holtmann',
#  'AbdallahJallow2',
#  'thothiel',
#  'TysonLester',
#  'lajlafetic',
#  'CASSIS_Bonn',
#  'DasRechtsportal',
#  'LiterallySimon',
#  'silkejaeger',
#  '_RafaelLoss',
#  'tdezan21',
#  'publicplan_GmbH',
#  'dmonett',
#  'sreekanthmreddy',
#  'IntHealthAI',
#  'mariodomisse',
#  'ScotJasper',
#  'CollinsADickso1',
#  'roennekus',
#  's_steinicke',
#  'JerchelPaul',
#  'LSMueller',
#  'SophieCFischer',
#  'tobiasknobloch',
#  'CChucholowski',
#  'AlexanderKnig',
#  'auslandsinfo',
#  'BRLObeer',
#  'FelixSaysHey',
#  'paulina_glass',
#  'CarlaHustedt',
#  'd_voelsen',
#  'christodros',
#  'KieranSaggar',
#  'witichind',
#  'heinzundmaier',
#  'm_huotari',
#  'maria_axente',
#  'manouatwork',
#  'AnjaTuerkan',
#  'DevinFiachra',
#  '_alexfuture',
#  'rjaeger',
#  'loadev',
#  'NWarnecke',
#  'BrigitteLutz',
#  'nutsernahme',
#  'cknebel79',
#  'Armin_Rz',
#  'MeisterAnatol',
#  'RennSteph',
#  'EFI_Kommission',
#  'hendrikfrank',
#  'gloptimist',
#  'anncathrin87',
#  'pueschnerm',
#  'wi00194',
#  'annkako06',
#  'somed',
#  'frageamt',
#  'dvolps',
#  'bnjmnsbl',
#  'jkleske',
#  'BuBernd',
#  'MeikeErnst',
#  'ikc300',
#  'Sylvie76293640',
#  'Prinze484',
#  'schuessler_c',
#  'degepolCOM',
#  'Robertojt',
#  'lena_ulbricht',
#  'JulianNoahP',
#  'TimmSchulze',
#  'torstenstaab',
#  'weitvonhier',
#  'ricardawgnr',
#  'D_Feser',
#  'maxneufeind',
#  'JoernPL',
#  'a_beranek',
#  'GregorReisch',
#  'maikkisi',
#  'Fabio_Tho',
#  'toridykes',
#  'IbrahimKoeran',
#  'weidmensch',
#  'bressansar',
#  'PolicyCorner',
#  'jenniferguay7',
#  'T313Big',
#  'AlgorithmXLab',
#  'BigIdeasPodcast',
#  '_WeeBeyH',
#  'bernstmeng',
#  't0mez',
#  'h_lahmann',
#  'JPKleinhans',
#  'wearelaivly',
#  'EmmaTruswell',
#  'seabassberlin',
#  'Ph_Lorenz',
#  'Hay_Berlin',
#  'bytes_knowledge',
#  'marlenefloyd',
#  'droecher',
#  'jantdm',
#  'hugozylb',
#  'perceptic0n',
#  'juschuetze',
#  'St_Heumann',
#  'marc_becker',
#  'sarannnna',
#  'Tabea_Bzz',
#  'contact2r',
#  'NZahn42',
#  'z_edian',
#  'n_ali_berlin',
#  'snv_berlin',
#  'SirJacobSaslow',
#  'n_reschen',
#  'goldkl4ng',
#  'jimenezroy']

# %%
handles = list(followers_df['Handle'])
tweets = pd.DataFrame()

for handle in handles[0:5]:
    tweets_handle = pd.DataFrame(get_tweets(handle))
    tweets_handle['Handle'] = handle
    tweets = pd.concat([tweets, tweets_handle], axis=0)
    
tweets.head()
# Out:
#                                                    0          Handle
# 0  RT @z_edian: Unser @snv_berlin Expert:innenwor...  christinacrupp
# 0  RT @gabonn: Die Deutsche Umwelthilfe hat einen...         joscchh
# 1  RT @Bonnentdecken: Wir @joscchh und ich möchte...         joscchh
# 2  RT @katjadoerner: Über meine ersten 100 Tage a...         joscchh
# 3  I'm discussing “Zukunft der Bonner Innenstadt ...         joscchh

# %%
tweets['Handle'].value_counts()
# Out:
# JohnMillerTX      20
# rosannafanni      20
# lottielane_       20
# joscchh           20
# christinacrupp     1
# Name: Handle, dtype: int64

# %%
tweets.rename(columns={0: 'Tweets'}, inplace=True)
tweets.head()
# Out:
#                                               Tweets          Handle
# 0  RT @z_edian: Unser @snv_berlin Expert:innenwor...  christinacrupp
# 0  RT @gabonn: Die Deutsche Umwelthilfe hat einen...         joscchh
# 1  RT @Bonnentdecken: Wir @joscchh und ich möchte...         joscchh
# 2  RT @katjadoerner: Über meine ersten 100 Tage a...         joscchh
# 3  I'm discussing “Zukunft der Bonner Innenstadt ...         joscchh

# %% [markdown]
# ## What other sort of meta data can I extract from the tweets?
# Consider getting date/time stamp and location of each tweet and adding it to the df

# %% [markdown]
# ### Extracting other meta data from tweepy internal methods:
#
# Doesn't work on tweets df created, testing below on my own tweets:

# %%
def get_user_tweets(api, username):
        """Return a list of all tweets from the authenticated API"""
        tweets = []
        for status in tweepy.Cursor(api.user_timeline, screen_name=username).items():
            tweets.append(status)
        return tweets 

alltweets = get_user_tweets(api, username='kate_saslow')

print("Number of tweets extracted: {}.\n".format(len(alltweets)))
# Out:
# Number of tweets extracted: 181.

# %%
testtweets = get_user_tweets(api, username='SirJacobSaslow')

print("Number of tweets extracted: {}.\n".format(len(testtweets)))
# Out:
# Number of tweets extracted: 27.

# %%
print("5 recent tweets:\n")
for tweet in alltweets[:5]:
    print(tweet.text)
    print()
# Out:
# 5 recent tweets:
#
# RT @Fabian_Reetz: #Job-Alert 📣
# You are into #sustainability or #energytransition and know how to code?
#
# We at @100ProzentEE are looking fo…
#
# @jimenezroy All of them 🙃
#
# @z_edian @realDa_Kir @MZinkanell @HonkHase ich mach gerade einen Remote/Teilzeit/englischen Kurs mit Ironhack Berli… https://t.co/1PKpzdNoad
#
# @noatamir Thanks for this! I have been trying to decide which to use, this is super timely and helpful 🙃
#
# RT @DerenicByrd: Kalief Browder allegedly stole a backpack at 16, spent 3 yrs at Riker's Island without trial.
#
# Riley Williams stole a lapt…

# %%
# We create a pandas DataFrame as follows
# Note: We loop through each element and add it to the DataFrame
data = pd.DataFrame(data=[tweet.text for tweet in alltweets], columns=['Tweets'])

# We display the first 10 elements of the DataFrame:
display(data.head(10))
# Out:
#                                               Tweets
# 0  RT @Fabian_Reetz: #Job-Alert 📣\nYou are into #...
# 1                          @jimenezroy All of them 🙃
# 2  @z_edian @realDa_Kir @MZinkanell @HonkHase ich...
# 3  @noatamir Thanks for this! I have been trying ...
# 4  RT @DerenicByrd: Kalief Browder allegedly stol...
# 5  RT @DPZ_Berlin: Twitter, Facebook &amp; Co. sp...
# 6    RT @CoriBush: Squad up. https://t.co/bp2KATL22R
# 7  RT @snv_berlin: Ein ereignisreiches Jahr in #T...
# 8  RT @TspBackgroundDi: Im #Porträt: Pegah Maham,...
# 9  RT @nicsigni: both a blessing and curse that m...

# %%
print(dir(alltweets[0]))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_api', '_json', 'author', 'contributors', 'coordinates', 'created_at', 'destroy', 'entities', 'favorite', 'favorite_count', 'favorited', 'geo', 'id', 'id_str', 'in_reply_to_screen_name', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'is_quote_status', 'lang', 'parse', 'parse_list', 'place', 'retweet', 'retweet_count', 'retweeted', 'retweets', 'source', 'source_url', 'text', 'truncated', 'user']

# %%
# Print a selection of attributes from the first Tweet
print(alltweets[0].id)
print(alltweets[0].created_at)
print(alltweets[0].source)
print(alltweets[0].favorite_count)
print(alltweets[0].retweet_count)
print(alltweets[0].geo)
print(alltweets[0].coordinates)
print(alltweets[0].entities)
# Out:
# 1352976222314180608
# 2021-01-23 13:47:23
# Twitter Web App
# 2
# 0
# None
# None
# {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'z_edian', 'name': 'Sven Herpig', 'id': 250064912, 'id_str': '250064912', 'indices': [0, 8]}, {'screen_name': 'realDa_Kir', 'name': 'David', 'id': 248405654, 'id_str': '248405654', 'indices': [9, 20]}, {'screen_name': 'MZinkanell', 'name': 'Michael Zinkanell', 'id': 1235606430473994246, 'id_str': '1235606430473994246', 'indices': [21, 32]}, {'screen_name': 'HonkHase', 'name': 'Manuel Atug', 'id': 1123680822064754688, 'id_str': '1123680822064754688', 'indices': [33, 42]}], 'urls': [{'url': 'https://t.co/1PKpzdNoad', 'expanded_url': 'https://twitter.com/i/web/status/1352976222314180608', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}

# %%
print(testtweets[0].id)
print(testtweets[0].created_at)
print(testtweets[0].source)
print(testtweets[0].favorite_count)
print(testtweets[0].retweet_count)
print(testtweets[0].geo)
print(testtweets[0].coordinates)
print(testtweets[0].entities)
# Out:
# 1181903719803301890
# 2019-10-09 12:06:20
# Twitter for iPhone
# 0
# 51922
# None
# None
# {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'BillKristol', 'name': 'Bill Kristol', 'id': 2800581040, 'id_str': '2800581040', 'indices': [3, 15]}], 'urls': []}

# %%
import numpy as np
# Add attributes of interest
data['len']  = np.array([len(tweet.text) for tweet in alltweets])
data['ID']   = np.array([tweet.id for tweet in alltweets])
data['Date'] = np.array([tweet.created_at for tweet in alltweets])
data['geo'] = np.array([tweet.geo for tweet in alltweets])
data['Likes']  = np.array([tweet.favorite_count for tweet in alltweets])
data['RTs']    = np.array([tweet.retweet_count for tweet in alltweets])

# Display of first 10 elements from DataFrame
display(data.head(10))
# Out:
#                                               Tweets  len  \
# 0  @z_edian @realDa_Kir @MZinkanell @HonkHase ich...  140
# 1  @noatamir Thanks for this! I have been trying ...  104
# 2  RT @DerenicByrd: Kalief Browder allegedly stol...  140
# 3  RT @DPZ_Berlin: Twitter, Facebook &amp; Co. sp...  144
# 4    RT @CoriBush: Squad up. https://t.co/bp2KATL22R   47
# 5  RT @snv_berlin: Ein ereignisreiches Jahr in #T...  140
# 6  RT @TspBackgroundDi: Im #Porträt: Pegah Maham,...  140
# 7  RT @nicsigni: both a blessing and curse that m...  118
# 8  @askans I believe that stronger EU-US cooperat...  140
# 9  @FeestChristoph @EU_Commission @BMBF_Bund Than...   94
#
#                     ID                Date   geo  Likes     RTs
# 0  1352976222314180608 2021-01-23 13:47:23  None      2       0
# 1  1352973752011776000 2021-01-23 13:37:34  None      1       0
# 2  1352616684662771713 2021-01-22 13:58:42  None      0  195477
# 3  1349280755109785608 2021-01-13 09:02:55  None      0       6
# 4  1345808234666463237 2021-01-03 19:04:21  None      0   12991
# 5  1339912031613415428 2020-12-18 12:34:57  None      0       8
# 6  1339556304294207496 2020-12-17 13:01:25  None      0       5
# 7  1338530120450117633 2020-12-14 17:03:44  None      0      17
# 8  1336221005942026240 2020-12-08 08:08:08  None      1       0
# 9  1336219433430298624 2020-12-08 08:01:53  None      0       0

# %%
testdf = pd.DataFrame(data=[tweet.text for tweet in testtweets], columns=['Tweets'])

testdf['len']  = np.array([len(tweet.text) for tweet in testtweets])
testdf['ID']   = np.array([tweet.id for tweet in testtweets])
testdf['Date'] = np.array([tweet.created_at for tweet in testtweets])
testdf['geo'] = np.array([tweet.geo for tweet in testtweets])
testdf['Likes']  = np.array([tweet.favorite_count for tweet in testtweets])
testdf['RTs']    = np.array([tweet.retweet_count for tweet in testtweets])

# Display of first 10 elements from DataFrame
display(testdf.head(10))
# Out:
#                                               Tweets  len  \
# 0  RT @BillKristol: Lindsey Graham: A president w...  140
# 1  RT @DetroitPistons: Reggie Jackson #NBAVote \n...   84
# 2         #NBAVote Drummond  https://t.co/qkKDCdy69P   42
# 3  RT @espn: That's ten straight wins for the @Ti...  118
# 4  “@espn: College Football: Approaching fast -&g...  138
# 5     @RapGenius Welcome to Atlanta remix, heeeyyyyy   46
# 6  RT @SeinfeldToday: George is briefly implicate...  129
# 7  RT @espn: Miguel Cabrera is the 1st player in ...  129
# 8  RT @JustinVerlander: #BackBenoit #BackBenoit #...   92
# 9  RT @JustinVerlander: RT &amp; help me #BackBen...  144
#
#                     ID                Date   geo  Likes    RTs
# 0  1181903719803301890 2019-10-09 12:06:20  None      0  51922
# 1   687340078138552320 2016-01-13 18:26:59  None      0    333
# 2   684585456919433216 2016-01-06 04:01:06  None      0      1
# 3   364925099461591040 2013-08-07 01:44:58  None      0    584
# 4   363711746172649472 2013-08-03 17:23:32  None      0      0
# 5   362590532200964096 2013-07-31 15:08:14  None      0      0
# 6   360087109337485312 2013-07-24 17:20:31  None      0   1993
# 7   355718347704373249 2013-07-12 16:00:37  None      0   2420
# 8   355352968603774977 2013-07-11 15:48:44  None      0   2269
# 9   355352926258069505 2013-07-11 15:48:34  None      0   5136

# %% [markdown]
# Now: before applying the for loop to the entire list of handles in the friends_df, consider what other sort of meta data I want from the tweets. Do I also want the date/time stamp? GEOCODE? etc. This way, I am only making one call to the API and getting all the meta data in one fell swoop.

# %%
# https://github.com/RodolfoFerro/pandas_twitter/blob/master/01-extracting-data.md

# %% [markdown]
# #### Okay, got it to work by entering a specific username. How can I have it iterate through my handles list?

# %%
# write new function that gets more data, not just .text
# see internal methods of tweepy for other meta data: https://github.com/RodolfoFerro/pandas_twitter/blob/master/01-extracting-data.md
# same link as used below!

def get_tweet_meta_data(handle):
    """ This function gets not only tweets.text but also other useful meta data using tweepy's internal method.
    Not sure I will need the other data, but this function will generate the important data in lists."""
    
    # extract 200 tweets
    number_tweets = 200
    tweets = api.user_timeline(screen_name=handle)
    
    # Empty array
    texts = []
    ids = []
    timestamps = []
    geocodes = []
    
    # create array of tweet info: username, tweet id, date/time, text, location
    tweets_text_for_csv = [tweet.text for tweet in tweets]
    tweets_id_for_csv = [tweet.id for tweet in tweets]
    tweets_createdat_for_csv = [tweet.created_at for tweet in tweets]
    tweets_geo_for_csv = [tweet.geo for tweet in tweets]
    
    for i in tweets_text_for_csv:
        texts.append(i)
        
    for j in tweets_id_for_csv:
        ids.append(j)
        
    for k in tweets_createdat_for_csv:
        timestamps.append(k)
        
    for l in tweets_geo_for_csv:
        geocodes.append(l)
        
    return texts, ids, timestamps, geocodes

# %%
get_tweet_meta_data('SirJacobSaslow')
# Out:
# (["RT @BillKristol: Lindsey Graham: A president who doesn't comply with Congressional requests for information is subject to impeachment. http…",
#   'RT @DetroitPistons: Reggie Jackson #NBAVote \n\n1 RT = 1 vote! https://t.co/bJSHdjMAW6',
#   '#NBAVote Drummond  https://t.co/qkKDCdy69P',
#   "RT @espn: That's ten straight wins for the @Tigers. The Motor City's starting to put the AL Central in cruise control.",
#   '“@espn: College Football: Approaching fast -&gt; http://t.co/3zAYnhXp26” Espn giving shoutouts to UMICH on the regs #goblue #rosebowlbound',
#   '@RapGenius Welcome to Atlanta remix, heeeyyyyy',
#   'RT @SeinfeldToday: George is briefly implicated in the latest Anthony Weiner scandal because his OKCupid handle is Carlos Danger.',
#   'RT @espn: Miguel Cabrera is the 1st player in major league history with 30 HR and 90 RBI before the All-Star break. #NotoriousMIG',
#   'RT @JustinVerlander: #BackBenoit #BackBenoit #BackBenoit #BackBenoit #BackBenoit #BackBenoit',
#   'RT @JustinVerlander: RT &amp; help me #BackBenoit for Final Vote in the 2013 #ASG! One of my followers who RTs will win 2 tix to an upcoming ga…',
#   '“@espn: This is not a player card for a video game. This is a player card for an actual MLB stud -&gt; http://t.co/QndvPYtfFK” #miggygoboom',
#   "RT @AdamSchefter: Jags don't list Denard Robinson's position as QB, WR or RB - positions he played in college. List it as OW. Offensive wea…",
#   '@kleintron clear eyes, full hearts #cantlose',
#   'Best hitter in baseball? ✔ Best pitcher in baseball? ✔ #TigersGoBoom',
#   "RT @stoolpresidente: I feel sad for everybody who went to a college whose team isn't in the National Championship game tonight",
#   'RT @Datsyuk13: Go Blue!',
#   "RT @ESPNStatsInfo: Grinnell's (Div. III) Jack Taylor scored 138 points tonight against Faith Baptist Bible - the most points in a single ...",
#   'Me with my homie @cartiersims in Ann Arbor http://t.co/itVWiQVT',
#   'How bout some playoff baseball http://t.co/yxnlRBXY'],
#  [1181903719803301890,
#   687340078138552320,
#   684585456919433216,
#   364925099461591040,
#   363711746172649472,
#   362590532200964096,
#   360087109337485312,
#   355718347704373249,
#   355352968603774977,
#   355352926258069505,
#   354237825190854658,
#   350256935091707907,
#   346128145663008768,
#   324247560560730113,
#   321345978072453120,
#   320754154731614208,
#   271095952826327041,
#   261958501574782976,
#   254694359683973121],
#  [datetime.datetime(2019, 10, 9, 12, 6, 20),
#   datetime.datetime(2016, 1, 13, 18, 26, 59),
#   datetime.datetime(2016, 1, 6, 4, 1, 6),
#   datetime.datetime(2013, 8, 7, 1, 44, 58),
#   datetime.datetime(2013, 8, 3, 17, 23, 32),
#   datetime.datetime(2013, 7, 31, 15, 8, 14),
#   datetime.datetime(2013, 7, 24, 17, 20, 31),
#   datetime.datetime(2013, 7, 12, 16, 0, 37),
#   datetime.datetime(2013, 7, 11, 15, 48, 44),
#   datetime.datetime(2013, 7, 11, 15, 48, 34),
#   datetime.datetime(2013, 7, 8, 13, 57, 33),
#   datetime.datetime(2013, 6, 27, 14, 18, 55),
#   datetime.datetime(2013, 6, 16, 4, 52, 35),
#   datetime.datetime(2013, 4, 16, 19, 46, 57),
#   datetime.datetime(2013, 4, 8, 19, 37, 6),
#   datetime.datetime(2013, 4, 7, 4, 25, 24),
#   datetime.datetime(2012, 11, 21, 3, 41, 26),
#   datetime.datetime(2012, 10, 26, 22, 32, 28),
#   datetime.datetime(2012, 10, 6, 21, 27, 22)],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None])

# %%
# Now try and add to the function to add the lists into a df:

def test_get_tweet_meta_data_to_df(handle):
    """ This function (TEST function for only 5 handles!) gets not only tweets.text but also other useful meta data using tweepy's internal method.
    Not sure I will need the other data, but this function will add it to a DataFrame in one step."""
# extract 200 tweets
    number_tweets = 200
    tweets = api.user_timeline(screen_name=handle)
    tweets_meta_df = pd.DataFrame()
    
    
    # Empty array
    texts = []
    ids = []
    timestamps = []
    geocodes = []
    
    # create array of tweet info: username, tweet id, date/time, text, location
    tweets_text_for_csv = [tweet.text for tweet in tweets]
    tweets_id_for_csv = [tweet.id for tweet in tweets]
    tweets_createdat_for_csv = [tweet.created_at for tweet in tweets]
    tweets_geo_for_csv = [tweet.geo for tweet in tweets]
    
    for i in tweets_text_for_csv:
        texts.append(i)
        
    for j in tweets_id_for_csv:
        ids.append(j)
        
    for k in tweets_createdat_for_csv:
        timestamps.append(k)
        
    for l in tweets_geo_for_csv:
        geocodes.append(l)
    
    for handle in handles[0:5]:
        twts_df = pd.DataFrame(get_tweets(handle))
        twts_df['Handle'] = handle
        twts_df['ID'] = pd.Series(ids)
        twts_df['CreatedAt'] = pd.Series(timestamps)
        twts_df['Location'] = pd.Series(geocodes)
        tweets_meta_df = pd.concat([tweets_meta_df, twts_df], axis=0, ignore_index=True)
    
    return tweets_meta_df

# %%
test_tweets = test_get_tweet_meta_data_to_df(handle)

# %%
test_tweets.shape
# Out:
# (81, 5)

# %% [markdown]
# ### After extracting tweets for all handles in Friends:
# After applying the function to all handles (from the Followers df), merge dataframes with tweets.text and followers (merge on handle), to get the location as well.
#
# Then, clean and standardize how location is written (by country) to use for analysis.

# %% [markdown]
# # Start here Tuesday to see if you can extract more.
# ##### Ask Christina/Filipa first if running it first thing will break anything.

# %%
def get_tweet_meta_data_to_df(handle):
    """ This function takes the test function above and applies it to all handles within the friends_df and gets not only tweets.text but also other useful meta data using tweepy's internal method.
    Not sure I will need the other data, but this function will add it to a DataFrame in one step."""

#     # extract 200 tweets
#     number_tweets = 200
    tweets = api.user_timeline(screen_name=handle)
    tweets_meta_df = pd.DataFrame()
    
    
    # Empty array
    texts = []
    ids = []
    timestamps = []
    geocodes = []
    
    # create array of tweet info: username, tweet id, date/time, text, location
    tweets_text_for_csv = [tweet.text for tweet in tweets]
    tweets_id_for_csv = [tweet.id for tweet in tweets]
    tweets_createdat_for_csv = [tweet.created_at for tweet in tweets]
    tweets_geo_for_csv = [tweet.geo for tweet in tweets]
    
    for i in tweets_text_for_csv:
        texts.append(i)
        
    for j in tweets_id_for_csv:
        ids.append(j)
        
    for k in tweets_createdat_for_csv:
        timestamps.append(k)
        
    for l in tweets_geo_for_csv:
        geocodes.append(l)
    
    for handle in handles:
        twts_df = pd.DataFrame(get_tweets(handle))
        twts_df['Handle'] = handle
        twts_df['ID'] = pd.Series(ids)
        twts_df['CreatedAt'] = pd.Series(timestamps)
        twts_df['Location'] = pd.Series(geocodes)
        tweets_meta_df = pd.concat([tweets_meta_df, twts_df], axis=0, ignore_index=True)
    
    return tweets_meta_df

# %%
df = get_tweet_meta_data_to_df(handle)
# Out:
# ---------------------------------------------------------------------------
# TweepError                                Traceback (most recent call last)
# <ipython-input-40-528e1a09b24b> in <module>
# ----> 1 df = get_tweet_meta_data_to_df(handle)
#
# <ipython-input-39-4858d5158ff6> in get_tweet_meta_data_to_df(handle)
#      34
#      35     for handle in handles:
# ---> 36         twts_df = pd.DataFrame(get_tweets(handle))
#      37         twts_df['Handle'] = handle
#      38         twts_df['ID'] = pd.Series(ids)
#
# <ipython-input-19-4c3d40cf76e4> in get_tweets(handle)
#       3     # extract 200 tweets
#       4     number_tweets = 200
# ----> 5     tweets = api.user_timeline(screen_name=handle)
#       6
#       7     # Empty array
#
# /opt/anaconda3/lib/python3.8/site-packages/tweepy/binder.py in _call(*args, **kwargs)
#     251                 return method
#     252             else:
# --> 253                 return method.execute()
#     254         finally:
#     255             method.session.close()
#
# /opt/anaconda3/lib/python3.8/site-packages/tweepy/binder.py in execute(self)
#     232                     raise RateLimitError(error_msg, resp)
#     233                 else:
# --> 234                     raise TweepError(error_msg, resp, api_code=api_error_code)
#     235
#     236             # Parse the response payload
#
# TweepError: Not authorized.

# %%
df.shape
# Out:
# (3892, 5)

# %% [markdown]
# ### Save df to csv to use for NLP at a later stage:

# %%
# code used in Movie Database Network Analysis
# cast_top200.to_csv('cast_top200.csv')

# %%
# NOTE: this is the small df, with only 3892 tweets.
# I tried to make a larger df using my FOLLOWERS not friends (followers = handles used in both functions)
# BUT I reached my limit and can't extract any more today. 
# try again tomorrow. 

df.to_csv('tweets_from_tweepy_small.csv')

# %%
df['Handle'].value_counts()
# note that there are only 200 friends, because this is the Twitter API maximum. Instead, make a df with tweets of followers, not friends!
# Out:
# RexChapman         20
# pinkiundbrain      20
# MichaelBarth       20
# Jodiscohen         20
# RashidaTlaib       20
#                    ..
# georges_delrieu     7
# DKorenke            5
# kat_lampert         2
# christinacrupp      1
# AnikaLange1         1
# Name: Handle, Length: 198, dtype: int64

# %%
# https://aadaobi.medium.com/exploring-twitter-api-and-data-using-tweepy-pandas-and-matplotlib-part-1-2ac07fcc4717

# choose criteria to search tweets by: keywords that have to do with women in tech?

search_items = ['tech', 'artificial intelligence', 'AI', 'STEM', 'women', 'data', 'gender']

def get_tweets(search_item):
    data = []
    counter = 0
    for tweet in tweepy.Cursor(api.search, q='\"{}\"'.format(search_item), count=100, lang='en', tweet_mode='extended').items():
        tweet_details = {}
        tweet_details['name'] = tweet.user.screen_name
        tweet_details['tweet'] = tweet.full_text
        tweet_details['retweets'] = tweet.retweet_count
        tweet_details['location'] = tweet.user.location
        tweet_details['followers'] = tweet.user.followers_count
        
        
        data.append(tweet_details)
        
        counter += 1
        if counter == 200:
            break
        else:
            pass
        with open('data/{}.json'.format(search_item), 'w') as f:
            json.dump(data, f)
        print('done!')
